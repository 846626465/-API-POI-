# %% [markdown]
# # 使用高德地图API(搜索POI)
# ## 1、首先，引入所需要用到的函数模块
# - 其中，pd是pandas模块的命名惯例，当你看到pd.DataFrame()时，你就知道它是引用pandas中的DataFrame函数。
# - DataFrame是一个常用到表格型数据结构，我们直接将其从pandas模块引出。

# %%
import requests,json,csv
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# ## 2、设置参数，使用requests模块请求返回数据
# - url，key，keywords，city，extensions，page都是可以向API请求的参数，更多详细的请求参数数据请查看API文件：[搜索api/search](http://lbs.amap.com/api/webservice/guide/api/search)
# - key可以在高德API自行申请。[key申请](https://lbs.amap.com/api/webservice/guide/create-project/get-key)
# - 将参数构造成字典形式并且赋值于data。
# - 使用requests来执行调用。并将URL和data传递给它，响应对象储存在req中。
# - Reqeusts支持以form表单形式发送post请求，只需要将请求的参数构造成一个字典。

# %%
url = 'https://restapi.amap.com/v3/place/text?parameters'
key = '9bawhsfklsdjfsljflksdjd34kktj3'
data = {'key':'b6a74ab04e9e5883bfcf92b4fe6126a2','keywords':'游戏场所','city':'广州','extensions':'all','page':'1'}    
req = requests.post(url,data)
data = req.json()

# %% [markdown]
# ### 查看返回的数据结果
# - API返回JSON格式的信息，因此上面使用了json()将这些数据转化为一个Python字典，并储存在data中。

# %%
data
# Out:
# {'status': '1',
#  'count': '351',
#  'info': 'OK',
#  'infocode': '10000',
#  'suggestion': {'keywords': [], 'cities': []},
#  'pois': [{'id': 'B0FFGY7LD2',
#    'parent': 'B0FFFE8QDN',
#    'name': '阿里游戏',
#    'tag': [],
#    'type': '体育休闲服务;娱乐场所;娱乐场所',
#    'typecode': '080300',
#    'biz_type': [],
#    'address': '冼村街道平云路163号平云广场B塔9层',
#    'location': '113.351179,23.118538',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413524800',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '珠江新城',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFH12EH4',
#    'parent': 'B00140WEWP',
#    'name': '游戏机',
#    'tag': [],
#    'type': '体育休闲服务;娱乐场所;游戏厅',
#    'typecode': '080305',
#    'biz_type': [],
#    'address': '棠下中山大道188号好又多超市(天河店)1层',
#    'location': '113.378325,23.125305',
#    'tel': '020-85468521',
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413535000',
#    'distance': [],
#    'navi_poiid': 'F49F011043_910376',
#    'entr_location': '113.378362,23.125571',
#    'business_area': '东圃',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': '3.2', 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFH0XZDX',
#    'parent': 'B00140TFHO',
#    'name': '游戏机(正佳广场)',
#    'tag': [],
#    'type': '体育休闲服务;娱乐场所;游戏厅',
#    'typecode': '080305',
#    'biz_type': [],
#    'address': '天河路228号正佳广场7层',
#    'location': '113.327023,23.132171',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413525620',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': '113.325849,23.13186',
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFIQ13G0',
#    'parent': 'B0FFFPG0BL',
#    'name': '好玩游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '天河北路保利中宇广场A座405',
#    'location': '113.341682,23.141075',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413526721',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '五山',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFIWUG03',
#    'parent': 'B00141IHBL',
#    'name': '可以游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '建中路59号雅爵大厦9楼',
#    'location': '113.371513,23.123505',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413524922',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFIB7SFF',
#    'parent': 'B00141JFBP',
#    'name': '果子游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '新港东路618号南丰汇大厦1805',
#    'location': '113.357293,23.097912',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440105',
#    'adname': '海珠区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413521821',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '新港东',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFFW7814',
#    'parent': 'B00140U0SG',
#    'name': '游戏币',
#    'tag': [],
#    'type': '购物服务;购物相关场所;购物相关场所',
#    'typecode': '060000',
#    'biz_type': [],
#    'address': '中山三路33号中华广场',
#    'location': '113.282794,23.126180',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440104',
#    'adname': '越秀区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413525201',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '大东',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': '3.5', 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFG8IBJZ',
#    'parent': 'B0FFG1PM81',
#    'name': '凤天游戏工作室',
#    'tag': [],
#    'type': '生活服务;生活服务场所;生活服务场所',
#    'typecode': '070000',
#    'biz_type': [],
#    'address': '黄埔大道中259号天润大厦南座1201室',
#    'location': '113.373140,23.120740',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413524912',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFH7NP95',
#    'parent': 'B0FFFS4DQK',
#    'name': '游戏机',
#    'tag': [],
#    'type': '体育休闲服务;休闲场所;游乐场',
#    'typecode': '080501',
#    'biz_type': [],
#    'address': '金洲商业街惠康街114号自贸城F1',
#    'location': '113.546878,22.802011',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440115',
#    'adname': '南沙区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413146302',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFHCS8H4',
#    'parent': 'B0FFFFJXRD',
#    'name': '游戏区(新都汇购物广场)',
#    'tag': [],
#    'type': '体育休闲服务;休闲场所;游乐场',
#    'typecode': '080501',
#    'biz_type': [],
#    'address': '同德围西槎路96号新都汇购物广场F3层',
#    'location': '113.236161,23.158265',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440111',
#    'adname': '白云区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413518822',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '1',
#    'indoor_data': {'cpid': 'B0FFFFJXRD',
#     'floor': '3',
#     'truefloor': 'F3',
#     'cmsid': 'GD0012050210300041'},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFG1PLBL',
#    'parent': 'B00141RCGR',
#    'name': '火羽游戏',
#    'tag': [],
#    'type': '体育休闲服务;娱乐场所;娱乐场所',
#    'typecode': '080300',
#    'biz_type': [],
#    'address': '天河北路908号高科大厦B座29层',
#    'location': '113.345001,23.140530',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413526721',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '五山',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFGBUCJE',
#    'parent': [],
#    'name': '银汉游戏',
#    'tag': [],
#    'type': '体育休闲服务;娱乐场所;娱乐场所',
#    'typecode': '080300',
#    'biz_type': [],
#    'address': '中山大道科韵路33-49号方圆E时光西座3A楼08室',
#    'location': '113.374279,23.127470',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413525902',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': '3.5', 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFHCHBIV',
#    'parent': 'B0FFHWFNMZ',
#    'name': '红鼎游戏',
#    'tag': [],
#    'type': '体育休闲服务;娱乐场所;娱乐场所',
#    'typecode': '080300',
#    'biz_type': [],
#    'address': '东环街番禺大道北555号番禺节能科技园内天安科技产业大厦2座801室',
#    'location': '113.368417,22.979799',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440113',
#    'adname': '番禺区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413327911',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': '3.5', 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFJ11O50',
#    'parent': [],
#    'name': '北鱼游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '天河路490号壬丰大厦18楼',
#    'location': '113.335099,23.132844',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413525622',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFIN8XHY',
#    'parent': [],
#    'name': '龙族游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '天河路490号壬丰大厦38楼3808室',
#    'location': '113.334930,23.132816',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413525622',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': '113.335226,23.132665',
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFIQFO45',
#    'parent': 'B00140TZYH',
#    'name': '风趣游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '龙怡路117号银汇大厦2806',
#    'location': '113.345345,23.143965',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413527701',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '五山',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFH2THMN',
#    'parent': [],
#    'name': '网易游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '金穗路62号侨鑫国际',
#    'location': '113.321904,23.122328',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413524522',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '珠江新城',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFI6STJB',
#    'parent': 'B0FFG9IQT2',
#    'name': '天赐游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '建中路66号佳都商务大厦东塔703',
#    'location': '113.370654,23.122657',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413524921',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFIZ6ZKM',
#    'parent': 'B0FFG2DAE9',
#    'name': '考拉游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '科韵路16号广州信息港E栋网易大厦10楼',
#    'location': '113.373230,23.126164',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413525902',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': [],
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []},
#   {'id': 'B0FFIP4HKH',
#    'parent': 'B0FFGS1EXH',
#    'name': '乐众游戏',
#    'tag': [],
#    'type': '体育休闲服务;体育休闲服务场所;体育休闲服务场所',
#    'typecode': '080000',
#    'biz_type': [],
#    'address': '科韵中路119号金悦大厦116室',
#    'location': '113.375931,23.131767',
#    'tel': [],
#    'postcode': [],
#    'website': [],
#    'email': [],
#    'pcode': '440000',
#    'pname': '广东省',
#    'citycode': '020',
#    'cityname': '广州市',
#    'adcode': '440106',
#    'adname': '天河区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'gridcode': '3413535020',
#    'distance': [],
#    'navi_poiid': [],
#    'entr_location': [],
#    'business_area': '上社村',
#    'exit_location': [],
#    'match': '0',
#    'recommend': '0',
#    'timestamp': [],
#    'alias': [],
#    'indoor_map': '0',
#    'indoor_data': {'cpid': [], 'floor': [], 'truefloor': [], 'cmsid': []},
#    'groupbuy_num': '0',
#    'discount_num': '0',
#    'biz_ext': {'rating': [], 'cost': []},
#    'event': [],
#    'children': [],
#    'photos': []}]}

# %% [markdown]
# ## 3、使用pd.DataFrame对数据进行处理
# - 使用DataFrame将data数据转换为表格型数据结构。

# %%
pois = data['pois']
frame = DataFrame(pois)

# %% [markdown]
# ### 查看数据结果
# - 切片索引前五行来看。

# %%
frame[:5]
# Out:
#    adcode                 address adname alias                        biz_ext  \
# 0  440106     冼村街道平云路163号平云广场B塔9层    天河区    []     {'rating': [], 'cost': []}
# 1  440106  棠下中山大道188号好又多超市(天河店)1层    天河区    []  {'rating': '3.2', 'cost': []}
# 2  440106           天河路228号正佳广场7层    天河区    []     {'rating': [], 'cost': []}
# 3  440106         天河北路保利中宇广场A座405    天河区    []     {'rating': [], 'cost': []}
# 4  440106            建中路59号雅爵大厦9楼    天河区    []     {'rating': [], 'cost': []}
#
#   biz_type business_area children citycode cityname   ...   postcode  \
# 0       []          珠江新城       []      020      广州市   ...         []
# 1       []            东圃       []      020      广州市   ...         []
# 2       []            []       []      020      广州市   ...         []
# 3       []            五山       []      020      广州市   ...         []
# 4       []            []       []      020      广州市   ...         []
#
#   recommend shopid shopinfo tag           tel timestamp  \
# 0         0     []        0  []            []        []
# 1         0     []        0  []  020-85468521        []
# 2         0     []        0  []            []        []
# 3         0     []        0  []            []        []
# 4         0     []        0  []            []        []
#
#                        type typecode website
# 0          体育休闲服务;娱乐场所;娱乐场所   080300      []
# 1           体育休闲服务;娱乐场所;游戏厅   080305      []
# 2           体育休闲服务;娱乐场所;游戏厅   080305      []
# 3  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000      []
# 4  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000      []
#
# [5 rows x 41 columns]

# %% [markdown]
# ## 4、使用pd.DataFrame处理POI信息列表栏位
# - DataFrame的columns参数控制栏位的顺序
# - 我们可以用添加字典键值的办法来为列表结构添加它所没有的信息，比如：keywords。

# %%
frame = DataFrame(frame,columns=['keywords','id','name','type','typecode','location',' tel','pname','pcode','cityname','citycode','adname','adcode'])
frame['keywords']='游戏场所'

# %% [markdown]
# ### 查看数据结果
# - 如下图，它已经按我们想要的排列顺序排列，并且添加了keywords值。

# %%
frame[:5]
# Out:
#   keywords          id       name                      type typecode  \
# 0     游戏场所  B0FFGY7LD2       阿里游戏          体育休闲服务;娱乐场所;娱乐场所   080300
# 1     游戏场所  B0FFH12EH4        游戏机           体育休闲服务;娱乐场所;游戏厅   080305
# 2     游戏场所  B0FFH0XZDX  游戏机(正佳广场)           体育休闲服务;娱乐场所;游戏厅   080305
# 3     游戏场所  B0FFIQ13G0       好玩游戏  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000
# 4     游戏场所  B0FFIWUG03       可以游戏  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000
#
#                location   tel pname   pcode cityname citycode adname  adcode
# 0  113.351179,23.118538   NaN   广东省  440000      广州市      020    天河区  440106
# 1  113.378325,23.125305   NaN   广东省  440000      广州市      020    天河区  440106
# 2  113.327023,23.132171   NaN   广东省  440000      广州市      020    天河区  440106
# 3  113.341682,23.141075   NaN   广东省  440000      广州市      020    天河区  440106
# 4  113.371513,23.123505   NaN   广东省  440000      广州市      020    天河区  440106

# %% [markdown]
# ## 5、对数据进行输出
# - 分别使用pandas模块的to_json函数和to_csv来产出json文档和tsv文档。
# - 其中，tsv需要设置sep = '\t',及以制表符来进行分割。

# %%
frame.to_json("output.json" )
frame.to_csv("output.tsv",encoding="utf8",sep='\t')

# %% [markdown]
# ## 6、设置循环，迭代全部page返回的完整数据
# - 如果不设置循环迭代，一次请求只能的返回one page(page为API提供的一个控制页数参数)的数据。page的详细信息可以查看API文件：[搜索api/search](http://lbs.amap.com/api/webservice/guide/api/search)
# - 先为循环迭代设置一个pois的空列表，用来迭代更多的字典结构，其中原理涉及到data[pois]中的数据结构，看上文。
# - %d为格式化整型，将每次循环后的+1page赋值于'page'。
# - data[pois]的数据结构是列表嵌套多个字典的结构，每一个字典代表一个完整的poi信息。
# - 使用whie True：来进行数据循环，当条件满足时，使用break跳出循环。
# - 每次循环，使用列表函数extend来为空列表pois进行迭代赋值。
# - len(pois)表示pois中字典的数量(字典的数量及为迭代数据的数量)。
# - data['count']为API返回的数据之一，表示完整数据的数量，可看上data返回的详细信息来理解。
# - 当len(pois) = data['count']时，及pois列表中已经迭代了全部的数据，这及为循环结束的条件。
# - 每次循环为page+1。

# %%
url = 'https://restapi.amap.com/v3/place/text?parameters'
key = '9bawhsfklsdjfsljflksdjd34kktj3'
pois = []
page = 1    
while True:
    data = {'key':'b6a74ab04e9e5883bfcf92b4fe6126a2','keywords':'游戏场所','city':'广州','extensions':'all','page':'%d'%page}    
    req = requests.post(url,data)
    data = req.json()
    pois.extend(data['pois'])
    pois_counts = len(pois)   
    all_counts = int(data['count'])  
    if (pois_counts >= all_counts):  
        break                             
    else:
        page +=1

# %% [markdown]
# ## 7、将搜索POI包装成函数
# 理由：
# - 包装成函数可以更方便我们多次使用函数。
# - 方便用户更换输入的keywords和city等参数。
#
# 函数输入：
# - 关键词(keywords)
# - 地区代码(city)
#
# 函数返回：
#
# - poi数据的表格结构
# - json文档
# - tsv文档
#
# 产出文件使用%s格式字符串，使得文件名称和函数输入的keywords一致。

# %%
def APIpoi(keywords,city):
    url = 'https://restapi.amap.com/v3/place/text?parameters'
    key = '9bawhsfklsdjfsljflksdjd34kktj3'
    pois = []
    page = 1    
    while True:
        data = {'key':'b6a74ab04e9e5883bfcf92b4fe6126a2','keywords':keywords,'city':city,'extensions':'all','page':'%d'%page}    
        req = requests.post(url,data)
        data = req.json()
        pois.extend(data['pois'])
        no_pois_this_search = len(pois)   
        no_pois = int(data['count'])  
        if (no_pois_this_search >= no_pois):  
            break                             
        else:
            page +=1
          
    frame = DataFrame(pois)
    frame = DataFrame(frame,columns=['keywords','id','name','type','typecode','location',' tel','pname','pcode','cityname','citycode','adname','adcode'])
    frame['keywords']=keywords
    print(frame)
    frame.to_json("%s.json" %keywords)
    print("加载入json文件完成...")
    frame.to_csv("%s.tsv" %keywords,encoding="utf8",sep='\t')
    print("加载入tsv文件完成...")

# %% [markdown]
# ## 调用函数

# %%
APIpoi(keywords='游戏场所',city='广州')
# Out:
#     keywords          id                name                             type  \
# 0       游戏场所  B0FFGY7LD2                阿里游戏                 体育休闲服务;娱乐场所;娱乐场所
# 1       游戏场所  B0FFH12EH4                 游戏机                  体育休闲服务;娱乐场所;游戏厅
# 2       游戏场所  B0FFH0XZDX           游戏机(正佳广场)                  体育休闲服务;娱乐场所;游戏厅
# 3       游戏场所  B0FFIQ13G0                好玩游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 4       游戏场所  B0FFIWUG03                可以游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 5       游戏场所  B0FFIB7SFF                果子游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 6       游戏场所  B0FFFW7814                 游戏币               购物服务;购物相关场所;购物相关场所
# 7       游戏场所  B0FFG8IBJZ             凤天游戏工作室               生活服务;生活服务场所;生活服务场所
# 8       游戏场所  B0FFH7NP95                 游戏机                  体育休闲服务;休闲场所;游乐场
# 9       游戏场所  B0FFHCS8H4        游戏区(新都汇购物广场)                  体育休闲服务;休闲场所;游乐场
# 10      游戏场所  B0FFG1PLBL                火羽游戏                 体育休闲服务;娱乐场所;娱乐场所
# 11      游戏场所  B0FFGBUCJE                银汉游戏                 体育休闲服务;娱乐场所;娱乐场所
# 12      游戏场所  B0FFHCHBIV                红鼎游戏                 体育休闲服务;娱乐场所;娱乐场所
# 13      游戏场所  B0FFJ11O50                北鱼游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 14      游戏场所  B0FFIN8XHY                龙族游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 15      游戏场所  B0FFIQFO45                风趣游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 16      游戏场所  B0FFH2THMN                网易游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 17      游戏场所  B0FFI6STJB                天赐游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 18      游戏场所  B0FFIZ6ZKM                考拉游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 19      游戏场所  B0FFIP4HKH                乐众游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 20      游戏场所  B0FFHKEM4Q                三象游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 21      游戏场所  B0FFIQT33F                鱼悦游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 22      游戏场所  B0FFJO31PH                龙谷游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 23      游戏场所  B0FFJFLBYL                米亚游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 24      游戏场所  B0FFJXUR71                库洛游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 25      游戏场所  B0FFJBD70U                绝地游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 26      游戏场所  B0FFHX2MOS              广州四九游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 27      游戏场所  B0FFJGCIV1                猫耳游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 28      游戏场所  B0FFJ8QVHK                君海游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 29      游戏场所  B0FFGJ7F83                天拓游戏                 体育休闲服务;娱乐场所;娱乐场所
# ..       ...         ...                 ...                              ...
# 321     游戏场所  B0FFFPRVRY             骏腾棋牌娱乐室                  体育休闲服务;娱乐场所;棋牌室
# 322     游戏场所  B0FFI1NCSB                哲理韵动                 体育休闲服务;娱乐场所;娱乐场所
# 323     游戏场所  B0FFFY6SPT               棋趣棋牌室                  体育休闲服务;娱乐场所;棋牌室
# 324     游戏场所  B0FFJKW89S  咪哒K SHOW(东方宝泰购物广场)                 体育休闲服务;娱乐场所;娱乐场所
# 325     游戏场所  B0FFJ68U3R                庄臣动漫         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 326     游戏场所  B0FFGIZYX3         永顺棋艺会(进步二街)                  体育休闲服务;娱乐场所;棋牌室
# 327     游戏场所  B0FFFPWD5L          棋盛棋牌室(增槎路)                  体育休闲服务;娱乐场所;棋牌室
# 328     游戏场所  B0FFHV8MF6    小Q亲子乐园(高德置地广场·冬)                 体育休闲服务;娱乐场所;娱乐场所
# 329     游戏场所  B00141UPR0               阿鲁的部屋               购物服务;购物相关场所;购物相关场所
# 330     游戏场所  B00140U88L               威龙棋牌室  体育休闲服务;娱乐场所;棋牌室|体育休闲服务;运动场馆;台球厅
# 331     游戏场所  B0FFIRBO4N                精瑛游艺                  体育休闲服务;娱乐场所;游戏厅
# 332     游戏场所  B0FFIR2CKP               仙娱棋牌室                  体育休闲服务;娱乐场所;棋牌室
# 333     游戏场所  B0FFIQSWY8              金国儿童乐园                  体育休闲服务;休闲场所;游乐场
# 334     游戏场所  B0FFIQI7XC               龙梦宫动漫         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 335     游戏场所  B0FFIQDSUJ                泰逢游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 336     游戏场所  B0FFIQ9JZ1   JY.G AME PS4电玩体验店                  体育休闲服务;娱乐场所;游戏厅
# 337     游戏场所  B0FFIPZ8YO                缘友棋牌                  体育休闲服务;娱乐场所;棋牌室
# 338     游戏场所  B0FFIPSR88         樱井动漫(地王广场店)                  体育休闲服务;休闲场所;游乐场
# 339     游戏场所  B0FFIPRDUR                陈记棋牌                  体育休闲服务;娱乐场所;棋牌室
# 340     游戏场所  B0FFIP4HKH                乐众游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 341     游戏场所  B0FFIOQ9JM         趣味挖掘机(百信广场)                 体育休闲服务;娱乐场所;娱乐场所
# 342     游戏场所  B0FFIOB1WD               疯狂娃娃3                 体育休闲服务;娱乐场所;娱乐场所
# 343     游戏场所  B0FFINMOL5                开心棋牌                  体育休闲服务;娱乐场所;棋牌室
# 344     游戏场所  B0FFINHMAU              奥飞欢乐世界         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 345     游戏场所  B0FFIN8XHY                龙族游戏         体育休闲服务;体育休闲服务场所;体育休闲服务场所
# 346     游戏场所  B0FFIMVB0Z             逸之堂沐足棋牌                  体育休闲服务;娱乐场所;棋牌室
# 347     游戏场所  B0FFIMV8ST                荣华棋牌                  体育休闲服务;娱乐场所;棋牌室
# 348     游戏场所  B0FFIMV8E4         泰山原浆啤酒体验直营店               购物服务;购物相关场所;购物相关场所
# 349     游戏场所  B0FFIMSWPO                  麦秀                 体育休闲服务;娱乐场所;娱乐场所
# 350     游戏场所  B0FFIMPUN6             金山谷养老社区               商务住宅;商务住宅相关;商务住宅相关
#
#           typecode              location   tel pname   pcode cityname  \
# 0           080300  113.351179,23.118538   NaN   广东省  440000      广州市
# 1           080305  113.378325,23.125305   NaN   广东省  440000      广州市
# 2           080305  113.327023,23.132171   NaN   广东省  440000      广州市
# 3           080000  113.341682,23.141075   NaN   广东省  440000      广州市
# 4           080000  113.371513,23.123505   NaN   广东省  440000      广州市
# 5           080000  113.357293,23.097912   NaN   广东省  440000      广州市
# 6           060000  113.282794,23.126180   NaN   广东省  440000      广州市
# 7           070000  113.373140,23.120740   NaN   广东省  440000      广州市
# 8           080501  113.546878,22.802011   NaN   广东省  440000      广州市
# 9           080501  113.236161,23.158265   NaN   广东省  440000      广州市
# 10          080300  113.345001,23.140530   NaN   广东省  440000      广州市
# 11          080300  113.374279,23.127470   NaN   广东省  440000      广州市
# 12          080300  113.368417,22.979799   NaN   广东省  440000      广州市
# 13          080000  113.335099,23.132844   NaN   广东省  440000      广州市
# 14          080000  113.334930,23.132816   NaN   广东省  440000      广州市
# 15          080000  113.345345,23.143965   NaN   广东省  440000      广州市
# 16          080000  113.321904,23.122328   NaN   广东省  440000      广州市
# 17          080000  113.370654,23.122657   NaN   广东省  440000      广州市
# 18          080000  113.373230,23.126164   NaN   广东省  440000      广州市
# 19          080000  113.375931,23.131767   NaN   广东省  440000      广州市
# 20          080000  113.366850,23.095464   NaN   广东省  440000      广州市
# 21          080000  113.292882,23.338931   NaN   广东省  440000      广州市
# 22          080000  113.314552,23.089619   NaN   广东省  440000      广州市
# 23          080000  113.338730,23.126076   NaN   广东省  440000      广州市
# 24          080000  113.371961,23.126639   NaN   广东省  440000      广州市
# 25          080000  113.376968,23.123352   NaN   广东省  440000      广州市
# 26          080000  113.351369,23.118551   NaN   广东省  440000      广州市
# 27          080000  113.392624,23.115358   NaN   广东省  440000      广州市
# 28          080000  113.402710,23.124868   NaN   广东省  440000      广州市
# 29          080300  113.417407,23.176390   NaN   广东省  440000      广州市
# ..             ...                   ...   ...   ...     ...      ...
# 321         080306  113.384506,23.120516   NaN   广东省  440000      广州市
# 322         080300  113.331732,23.153613   NaN   广东省  440000      广州市
# 323         080306  113.386980,23.120210   NaN   广东省  440000      广州市
# 324         080300  113.324976,23.148073   NaN   广东省  440000      广州市
# 325         080000  113.317352,23.127010   NaN   广东省  440000      广州市
# 326         080306  113.235388,23.172495   NaN   广东省  440000      广州市
# 327         080306  113.234380,23.139335   NaN   广东省  440000      广州市
# 328         080300  113.327486,23.119974   NaN   广东省  440000      广州市
# 329         060000  113.317140,23.135000   NaN   广东省  440000      广州市
# 330  080306|080113  113.366356,23.120161   NaN   广东省  440000      广州市
# 331         080305  113.226675,23.212429   NaN   广东省  440000      广州市
# 332         080306  113.719455,23.163993   NaN   广东省  440000      广州市
# 333         080501  113.254033,23.204668   NaN   广东省  440000      广州市
# 334         080000  113.372065,22.967274   NaN   广东省  440000      广州市
# 335         080000  113.340454,23.138290   NaN   广东省  440000      广州市
# 336         080305  113.250009,23.125416   NaN   广东省  440000      广州市
# 337         080306  113.397851,22.937090   NaN   广东省  440000      广州市
# 338         080501  113.283497,23.125719   NaN   广东省  440000      广州市
# 339         080306  113.234553,23.159076   NaN   广东省  440000      广州市
# 340         080000  113.375931,23.131767   NaN   广东省  440000      广州市
# 341         080300  113.261779,23.194522   NaN   广东省  440000      广州市
# 342         080300  113.226859,23.177600   NaN   广东省  440000      广州市
# 343         080306  113.252540,23.162151   NaN   广东省  440000      广州市
# 344         080000  113.417260,23.131337   NaN   广东省  440000      广州市
# 345         080000  113.334930,23.132816   NaN   广东省  440000      广州市
# 346         080306  113.415585,23.165246   NaN   广东省  440000      广州市
# 347         080306  113.310149,23.099709   NaN   广东省  440000      广州市
# 348         060000  113.292763,23.067510   NaN   广东省  440000      广州市
# 349         080300  113.321879,23.095681   NaN   广东省  440000      广州市
# 350         120000  113.345387,22.979633   NaN   广东省  440000      广州市
#
#     citycode adname  adcode
# 0        020    天河区  440106
# 1        020    天河区  440106
# 2        020    天河区  440106
# 3        020    天河区  440106
# 4        020    天河区  440106
# 5        020    海珠区  440105
# 6        020    越秀区  440104
# 7        020    天河区  440106
# 8        020    南沙区  440115
# 9        020    白云区  440111
# 10       020    天河区  440106
# 11       020    天河区  440106
# 12       020    番禺区  440113
# 13       020    天河区  440106
# 14       020    天河区  440106
# 15       020    天河区  440106
# 16       020    天河区  440106
# 17       020    天河区  440106
# 18       020    天河区  440106
# 19       020    天河区  440106
# 20       020    海珠区  440105
# 21       020    白云区  440111
# 22       020    海珠区  440105
# 23       020    天河区  440106
# 24       020    天河区  440106
# 25       020    天河区  440106
# 26       020    天河区  440106
# 27       020    天河区  440106
# 28       020    天河区  440106
# 29       020    黄埔区  440112
# ..       ...    ...     ...
# 321      020    天河区  440106
# 322      020    天河区  440106
# 323      020    天河区  440106
# 324      020    天河区  440106
# 325      020    天河区  440106
# 326      020    白云区  440111
# 327      020    荔湾区  440103
# 328      020    天河区  440106
# 329      020    天河区  440106
# 330      020    天河区  440106
# 331      020    白云区  440111
# 332      020    增城区  440118
# 333      020    白云区  440111
# 334      020    番禺区  440113
# 335      020    天河区  440106
# 336      020    荔湾区  440103
# 337      020    番禺区  440113
# 338      020    越秀区  440104
# 339      020    白云区  440111
# 340      020    天河区  440106
# 341      020    白云区  440111
# 342      020    白云区  440111
# 343      020    越秀区  440104
# 344      020    天河区  440106
# 345      020    天河区  440106
# 346      020    天河区  440106
# 347      020    海珠区  440105
# 348      020    海珠区  440105
# 349      020    海珠区  440105
# 350      020    番禺区  440113
#
# [351 rows x 13 columns]
# 加载入json文件完成...
# 加载入tsv文件完成...
